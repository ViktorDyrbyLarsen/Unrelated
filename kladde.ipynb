# %%
from sympy import *

# %%
a = 16; b = 24; c = 8
b**2 - 4*a*c
# Out:
# 64

# %%
a = 16; b = 24/2; c = 8
(-(b) - (sqrt(((b)**2) - a*c)))/a
# Out:
# -1.00000000000000

# %%
x,y = symbols("x y")
s,r = symbols("s r")
w = s**2 + r*s + s - r
expr = w.subs(s,y-3).subs(r,x-y+3)
expr.simplify()
16*diff(expr,x,x)*24*diff(expr,x,y) + 8*diff(expr,y,y)
diff(expr,y)
# Out:
# x + 2

# %%
x,t = symbols("x t")
u = -2 - x - cos(7*pi*x/2) * exp(-245*pi**2/4 * t)
u.subs(x,1), diff(u,x).subs(x,0), u.subs(t,0)
# Out:
# (-3, -1, -x - cos(7*pi*x/2) - 2)
